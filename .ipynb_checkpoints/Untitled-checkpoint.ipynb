# %%
import pandas as pd
import numpy as np
import ast
import seaborn as sns
import matplotlib.pyplot as plt
from numbers import Number

# %%
file_path = 'books.csv'

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#         id                                               Book  \
# 0        0          The Restaurant at the End of the Universe
# 1        1                               The Name of the Rose
# 2        2                          The Clan of the Cave Bear
# 3        3                                        Firestarter
# 4        4                                             Cosmos
# ...    ...                                                ...
# 4395  4395                                      Sword Catcher
# 4396  4396                              The Covenant of Water
# 4397  4397                                Poverty, by America
# 4398  4398                       Finlay Donovan Jumps the Gun
# 4399  4399  Murder Your Employer: The McMasters Guide to H...
#
#                                     Series Release number              Author  \
# 0     The Hitchhiker's Guide to the Galaxy              2       Douglas Adams
# 1                                      NaN            NaN         Umberto Eco
# 2                         Earth's Children              1        Jean M. Auel
# 3                                      NaN            NaN        Stephen King
# 4                                      NaN            NaN          Carl Sagan
# ...                                    ...            ...                 ...
# 4395                         Sword Catcher              1     Cassandra Clare
# 4396                                   NaN            NaN  Abraham   Verghese
# 4397                                   NaN            NaN     Matthew Desmond
# 4398                        Finlay Donovan              3       Elle Cosimano
# 4399                                   NaN            NaN       Rupert Holmes
#
#                                             Description  Num Pages  \
# 0     Facing annihilation at the hands of the warlik...      250.0
# 1     The year is 1327. Benedictines in a wealthy It...      536.0
# 2     This novel of awesome beauty and power is a mo...      512.0
# 3     The Department of Scientific Intelligence (aka...      564.0
# 4     The story of fifteen billion years of cosmic e...      384.0
# ...                                                 ...        ...
# 4395  In the vibrant city-state of Castellane, the r...      624.0
# 4396  A stunning and magisterial new epic of love, f...      724.0
# 4397  The Pulitzer Prize–winning, bestselling author...      284.0
# 4398  Author and single mom Finlay Donovan has been ...      304.0
# 4399  A devilish thriller with a killer concept: The...      389.0
#
#                      Format  \
# 0                 Paperback
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Hardcover
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  Genres    Publication Date  \
# 0     ['Science Fiction', 'Fiction', 'Humor', 'Fanta...    October 12, 1980
# 1     ['Fiction', 'Historical Fiction', 'Mystery', '...     January 1, 1980
# 2     ['Historical Fiction', 'Fiction', 'Fantasy', '...     January 1, 1980
# 3     ['Horror', 'Fiction', 'Thriller', 'Science Fic...  September 29, 1980
# 4     ['Science', 'Nonfiction', 'Physics', 'Astronom...     January 1, 1980
# ...                                                 ...                 ...
# 4395  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...    October 10, 2023
# 4396  ['Fiction', 'Historical Fiction', 'India', 'Au...         May 2, 2023
# 4397  ['Nonfiction', 'Politics', 'Sociology', 'Histo...      March 21, 2023
# 4398  ['Mystery', 'Audiobook', 'Fiction', 'Mystery T...    January 31, 2023
# 4399  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...   February 21, 2023
#
#      Rating  Number of voters
# 0      4.21            283375
# 1      4.14            360732
# 2      4.09            264630
# 3      3.91            226270
# 4      4.39            144686
# ...     ...               ...
# 4395   3.85             12662
# 4396   4.49            111236
# 4397   4.30             25676
# 4398   3.82             46020
# 4399   3.90             19625
#
# [4400 rows x 12 columns]

# %%
column_to_sort = 'Rating'

df_sorted = df.sort_values(by=column_to_sort, ascending=False)

df_sorted
# Out:
#         id                                 Book                Series  \
# 391    391                 For Reading Out Loud                   NaN
# 3292  3292                    The Witch Is Back            Underworld
# 453    453             Ma Rainey's Black Bottom                   NaN
# 300    300                   The Color of Magic  Discworld, Rincewind
# 1542  1542  The Watsons Go to Birmingham - 1963                   NaN
# ...    ...                                  ...                   ...
# 2995  2995                 A Gate at the Stairs                   NaN
# 2882  2882                     A Katrina Moment                   NaN
# 2468  2468            The Jane Austen Book Club                   NaN
# 87      87                       The Green Book                   NaN
# 2671  2671               The Emperor's Children                   NaN
#
#      Release number                   Author  \
# 391             NaN     Margaret Mary Kimmel
# 3292              4             H.P. Mallory
# 453             NaN            August Wilson
# 300             1,1          Terry Pratchett
# 1542            NaN  Christopher Paul Curtis
# ...             ...                      ...
# 2995            NaN             Lorrie Moore
# 2882            NaN        Alexandra Everist
# 2468            NaN         Karen Joy Fowler
# 87              NaN          Muammar Gaddafi
# 2671            NaN            Claire Messud
#
#                                             Description  Num Pages  \
# 391   A comprehensive guide for parents lists more t...      266.0
# 3292  The witching hour has arrived in bestselling a...      368.0
# 453   The time is 1927. The place is a rundown recor...      111.0
# 300   In a world supported on the back of a giant tu...      228.0
# 1542  The Newbery Honor-winning American classic, \n...      224.0
# ...                                                 ...        ...
# 2995  A novel on the anxiety and disconnection of po...      322.0
# 2882  A Katrina Moment relates the tale of two lover...      160.0
# 2468  The Extraordinary \n Bestseller\n \n In Califo...      288.0
# 87                        English, Arabic (translation)        NaN
# 2671  From a writer “of near-miraculous perfection” ...      431.0
#
#                      Format  \
# 391               Hardcover
# 3292  Mass Market Paperback
# 453               Paperback
# 300               Paperback
# 1542              Paperback
# ...                     ...
# 2995              Hardcover
# 2882              Paperback
# 2468              Paperback
# 87            ['112 pages']
# 2671              Hardcover
#
#                                                  Genres   Publication Date  \
# 391                                      ['Nonfiction']    January 1, 1983
# 3292  ['Paranormal', 'Paranormal Romance', 'Romance'...       July 1, 2012
# 453   ['Plays', 'Drama', 'Fiction', 'Historical Fict...    January 1, 1984
# 300   ['Fantasy', 'Fiction', 'Humor', 'Comedy', 'Sci...   December 1, 1983
# 1542  ['Historical Fiction', 'Young Adult', 'Middle ...    January 1, 1995
# ...                                                 ...                ...
# 2995  ['Fiction', 'Novels', 'Contemporary', 'Literar...  September 1, 2009
# 2882                                                 []       May 19, 2008
# 2468  ['Fiction', 'Chick Lit', 'Romance', 'Contempor...     April 22, 2004
# 87    ['Politics', 'Nonfiction', 'Philosophy', 'Liby...    January 1, 1975
# 2671  ['Fiction', 'Contemporary', 'Novels', 'Literar...    August 29, 2006
#
#      Rating  Number of voters
# 391    real                16
# 3292   real              6155
# 453    real              3492
# 300    real            382549
# 1542   real             67297
# ...     ...               ...
# 2995   3.17             18113
# 2882   3.16                19
# 2468   3.10             69687
# 87     2.97              1330
# 2671   2.97             20860
#
# [4400 rows x 12 columns]

# %%
# Use apply and pd.to_numeric to check for non-integer values in the column
non_integer_rows = df[column_to_sort].apply(pd.to_numeric, errors='coerce').isna()

# Count the number of rows with non-integer values
count_non_integer_rows = non_integer_rows.sum()

# Display the count
print(f'The column "{column_to_sort}" has {count_non_integer_rows} rows with non-integer values.')
# Out:
# The column "Rating" has 67 rows with non-integer values.

# %%
# Replace 'column_x' with the actual name of the column you want to modify
column_to_modify = 'Rating'

def replace_non_numeric(value):
    try:
        # Try to convert the value to a float
        return float(value)
    except (ValueError, TypeError):
        # If conversion fails, generate a random float between 3.5 and 4.5
        return np.random.uniform(3.5, 4.5)

# Apply the custom function to the specified column
df[column_to_modify] = df[column_to_modify].apply(replace_non_numeric)

# Display the modified DataFrame
df
# Out:
#         id                                               Book  \
# 0        0          The Restaurant at the End of the Universe
# 1        1                               The Name of the Rose
# 2        2                          The Clan of the Cave Bear
# 3        3                                        Firestarter
# 4        4                                             Cosmos
# ...    ...                                                ...
# 4395  4395                                      Sword Catcher
# 4396  4396                              The Covenant of Water
# 4397  4397                                Poverty, by America
# 4398  4398                       Finlay Donovan Jumps the Gun
# 4399  4399  Murder Your Employer: The McMasters Guide to H...
#
#                                     Series Release number              Author  \
# 0     The Hitchhiker's Guide to the Galaxy              2       Douglas Adams
# 1                                      NaN            NaN         Umberto Eco
# 2                         Earth's Children              1        Jean M. Auel
# 3                                      NaN            NaN        Stephen King
# 4                                      NaN            NaN          Carl Sagan
# ...                                    ...            ...                 ...
# 4395                         Sword Catcher              1     Cassandra Clare
# 4396                                   NaN            NaN  Abraham   Verghese
# 4397                                   NaN            NaN     Matthew Desmond
# 4398                        Finlay Donovan              3       Elle Cosimano
# 4399                                   NaN            NaN       Rupert Holmes
#
#                                             Description  Num Pages  \
# 0     Facing annihilation at the hands of the warlik...      250.0
# 1     The year is 1327. Benedictines in a wealthy It...      536.0
# 2     This novel of awesome beauty and power is a mo...      512.0
# 3     The Department of Scientific Intelligence (aka...      564.0
# 4     The story of fifteen billion years of cosmic e...      384.0
# ...                                                 ...        ...
# 4395  In the vibrant city-state of Castellane, the r...      624.0
# 4396  A stunning and magisterial new epic of love, f...      724.0
# 4397  The Pulitzer Prize–winning, bestselling author...      284.0
# 4398  Author and single mom Finlay Donovan has been ...      304.0
# 4399  A devilish thriller with a killer concept: The...      389.0
#
#                      Format  \
# 0                 Paperback
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Hardcover
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  Genres    Publication Date  \
# 0     ['Science Fiction', 'Fiction', 'Humor', 'Fanta...    October 12, 1980
# 1     ['Fiction', 'Historical Fiction', 'Mystery', '...     January 1, 1980
# 2     ['Historical Fiction', 'Fiction', 'Fantasy', '...     January 1, 1980
# 3     ['Horror', 'Fiction', 'Thriller', 'Science Fic...  September 29, 1980
# 4     ['Science', 'Nonfiction', 'Physics', 'Astronom...     January 1, 1980
# ...                                                 ...                 ...
# 4395  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...    October 10, 2023
# 4396  ['Fiction', 'Historical Fiction', 'India', 'Au...         May 2, 2023
# 4397  ['Nonfiction', 'Politics', 'Sociology', 'Histo...      March 21, 2023
# 4398  ['Mystery', 'Audiobook', 'Fiction', 'Mystery T...    January 31, 2023
# 4399  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...   February 21, 2023
#
#       Rating  Number of voters
# 0       4.21            283375
# 1       4.14            360732
# 2       4.09            264630
# 3       3.91            226270
# 4       4.39            144686
# ...      ...               ...
# 4395    3.85             12662
# 4396    4.49            111236
# 4397    4.30             25676
# 4398    3.82             46020
# 4399    3.90             19625
#
# [4400 rows x 12 columns]

# %%
df_sorted = df.sort_values(by=column_to_modify, ascending=False)
df_sorted
# Out:
#         id                            Book  \
# 2542  2542  The Complete Calvin and Hobbes
# 3449  3449               Words of Radiance
# 1611  1611            It's a Magical World
# 4364  4364                    Magic Claims
# 3985  3985                    Know My Name
# ...    ...                             ...
# 2995  2995            A Gate at the Stairs
# 2882  2882                A Katrina Moment
# 2468  2468       The Jane Austen Book Club
# 87      87                  The Green Book
# 2671  2671          The Emperor's Children
#
#                                             Series Release number  \
# 2542                                           NaN            NaN
# 3449                        The Stormlight Archive              2
# 1611                             Calvin and Hobbes             11
# 4364  Kate Daniels: Wilmington Years, Kate Daniels         2,10.6
# 3985                                           NaN            NaN
# ...                                            ...            ...
# 2995                                           NaN            NaN
# 2882                                           NaN            NaN
# 2468                                           NaN            NaN
# 87                                             NaN            NaN
# 2671                                           NaN            NaN
#
#                  Author                                        Description  \
# 2542     Bill Watterson  [ \n\n\nBox Set\n\n\n | \nBook One\n | \nBook ...
# 3449  Brandon Sanderson  , Book Two of the Stormlight Archive, continue...
# 1611     Bill Watterson  When cartoonist Bill Watterson announced that ...
# 4364      Ilona Andrews  Kate and Curran have just settled into their n...
# 3985      Chanel Miller  She was known to the world as Emily Doe when s...
# ...                 ...                                                ...
# 2995       Lorrie Moore  A novel on the anxiety and disconnection of po...
# 2882  Alexandra Everist  A Katrina Moment relates the tale of two lover...
# 2468   Karen Joy Fowler  The Extraordinary \n Bestseller\n \n In Califo...
# 87      Muammar Gaddafi                      English, Arabic (translation)
# 2671      Claire Messud  From a writer “of near-miraculous perfection” ...
#
#       Num Pages          Format  \
# 2542     1456.0       Hardcover
# 3449     1087.0       Hardcover
# 1611      176.0       Paperback
# 4364      240.0  Kindle Edition
# 3985      384.0           ebook
# ...         ...             ...
# 2995      322.0       Hardcover
# 2882      160.0       Paperback
# 2468      288.0       Paperback
# 87          NaN   ['112 pages']
# 2671      431.0       Hardcover
#
#                                                  Genres    Publication Date  \
# 2542  ['Comics', 'Humor', 'Graphic Novels', 'Fiction...   September 6, 2005
# 3449  ['Fantasy', 'Fiction', 'Epic Fantasy', 'High F...       March 4, 2014
# 1611  ['Comics', 'Humor', 'Graphic Novels', 'Fiction...   September 1, 1996
# 4364  ['Urban Fantasy', 'Fantasy', 'Paranormal', 'Ma...       June 13, 2023
# 3985  ['Nonfiction', 'Memoir', 'Feminism', 'Audioboo...  September 24, 2019
# ...                                                 ...                 ...
# 2995  ['Fiction', 'Novels', 'Contemporary', 'Literar...   September 1, 2009
# 2882                                                 []        May 19, 2008
# 2468  ['Fiction', 'Chick Lit', 'Romance', 'Contempor...      April 22, 2004
# 87    ['Politics', 'Nonfiction', 'Philosophy', 'Liby...     January 1, 1975
# 2671  ['Fiction', 'Contemporary', 'Novels', 'Literar...     August 29, 2006
#
#       Rating  Number of voters
# 2542    4.81             39934
# 3449    4.76            335442
# 1611    4.73             28225
# 4364    4.72             10642
# 3985    4.71            190373
# ...      ...               ...
# 2995    3.17             18113
# 2882    3.16                19
# 2468    3.10             69687
# 87      2.97              1330
# 2671    2.97             20860
#
# [4400 rows x 12 columns]

# %%
print(f'The column "{df_sorted["Rating"]}" has {count_non_integer_rows} rows with non-integer values.')
# Out:
# The column "2542    4.81
# 3449    4.76
# 1611    4.73
# 4364    4.72
# 3985    4.71
#         ...
# 2995    3.17
# 2882    3.16
# 2468    3.10
# 87      2.97
# 2671    2.97
# Name: Rating, Length: 4400, dtype: float64" has 67 rows with non-integer values.

# %%
uniques = df["Rating"].unique()

types = [type(x) for x in uniques]
print(types)

uniques_non_numeric = [x for x in uniques if not isinstance(x, Number)]
print(uniques_non_numeric)
# Out:
# [<class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, <class 'numpy.float64'>, ...
# []

# %%
book_pages = df['Num Pages']

df = df[~book_pages.isnull()]

# final conversion now worked
df[['Num Pages']] = df[['Num Pages']].astype(int)

df
# Out:
# /tmp/ipykernel_6061/3032319327.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Num Pages']] = df[['Num Pages']].astype(int)
#         id                                               Book  \
# 0        0          The Restaurant at the End of the Universe
# 1        1                               The Name of the Rose
# 2        2                          The Clan of the Cave Bear
# 3        3                                        Firestarter
# 4        4                                             Cosmos
# ...    ...                                                ...
# 4395  4395                                      Sword Catcher
# 4396  4396                              The Covenant of Water
# 4397  4397                                Poverty, by America
# 4398  4398                       Finlay Donovan Jumps the Gun
# 4399  4399  Murder Your Employer: The McMasters Guide to H...
#
#                                     Series Release number              Author  \
# 0     The Hitchhiker's Guide to the Galaxy              2       Douglas Adams
# 1                                      NaN            NaN         Umberto Eco
# 2                         Earth's Children              1        Jean M. Auel
# 3                                      NaN            NaN        Stephen King
# 4                                      NaN            NaN          Carl Sagan
# ...                                    ...            ...                 ...
# 4395                         Sword Catcher              1     Cassandra Clare
# 4396                                   NaN            NaN  Abraham   Verghese
# 4397                                   NaN            NaN     Matthew Desmond
# 4398                        Finlay Donovan              3       Elle Cosimano
# 4399                                   NaN            NaN       Rupert Holmes
#
#                                             Description  Num Pages  \
# 0     Facing annihilation at the hands of the warlik...        250
# 1     The year is 1327. Benedictines in a wealthy It...        536
# 2     This novel of awesome beauty and power is a mo...        512
# 3     The Department of Scientific Intelligence (aka...        564
# 4     The story of fifteen billion years of cosmic e...        384
# ...                                                 ...        ...
# 4395  In the vibrant city-state of Castellane, the r...        624
# 4396  A stunning and magisterial new epic of love, f...        724
# 4397  The Pulitzer Prize–winning, bestselling author...        284
# 4398  Author and single mom Finlay Donovan has been ...        304
# 4399  A devilish thriller with a killer concept: The...        389
#
#                      Format  \
# 0                 Paperback
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Hardcover
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  Genres    Publication Date  \
# 0     ['Science Fiction', 'Fiction', 'Humor', 'Fanta...    October 12, 1980
# 1     ['Fiction', 'Historical Fiction', 'Mystery', '...     January 1, 1980
# 2     ['Historical Fiction', 'Fiction', 'Fantasy', '...     January 1, 1980
# 3     ['Horror', 'Fiction', 'Thriller', 'Science Fic...  September 29, 1980
# 4     ['Science', 'Nonfiction', 'Physics', 'Astronom...     January 1, 1980
# ...                                                 ...                 ...
# 4395  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...    October 10, 2023
# 4396  ['Fiction', 'Historical Fiction', 'India', 'Au...         May 2, 2023
# 4397  ['Nonfiction', 'Politics', 'Sociology', 'Histo...      March 21, 2023
# 4398  ['Mystery', 'Audiobook', 'Fiction', 'Mystery T...    January 31, 2023
# 4399  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...   February 21, 2023
#
#       Rating  Number of voters
# 0       4.21            283375
# 1       4.14            360732
# 2       4.09            264630
# 3       3.91            226270
# 4       4.39            144686
# ...      ...               ...
# 4395    3.85             12662
# 4396    4.49            111236
# 4397    4.30             25676
# 4398    3.82             46020
# 4399    3.90             19625
#
# [4366 rows x 12 columns]

# %%
df = df.fillna('Brak danych')
df
# Out:
#         id                                               Book  \
# 0        0          The Restaurant at the End of the Universe
# 1        1                               The Name of the Rose
# 2        2                          The Clan of the Cave Bear
# 3        3                                        Firestarter
# 4        4                                             Cosmos
# ...    ...                                                ...
# 4395  4395                                      Sword Catcher
# 4396  4396                              The Covenant of Water
# 4397  4397                                Poverty, by America
# 4398  4398                       Finlay Donovan Jumps the Gun
# 4399  4399  Murder Your Employer: The McMasters Guide to H...
#
#                                     Series Release number              Author  \
# 0     The Hitchhiker's Guide to the Galaxy              2       Douglas Adams
# 1                              Brak danych    Brak danych         Umberto Eco
# 2                         Earth's Children              1        Jean M. Auel
# 3                              Brak danych    Brak danych        Stephen King
# 4                              Brak danych    Brak danych          Carl Sagan
# ...                                    ...            ...                 ...
# 4395                         Sword Catcher              1     Cassandra Clare
# 4396                           Brak danych    Brak danych  Abraham   Verghese
# 4397                           Brak danych    Brak danych     Matthew Desmond
# 4398                        Finlay Donovan              3       Elle Cosimano
# 4399                           Brak danych    Brak danych       Rupert Holmes
#
#                                             Description  Num Pages  \
# 0     Facing annihilation at the hands of the warlik...        250
# 1     The year is 1327. Benedictines in a wealthy It...        536
# 2     This novel of awesome beauty and power is a mo...        512
# 3     The Department of Scientific Intelligence (aka...        564
# 4     The story of fifteen billion years of cosmic e...        384
# ...                                                 ...        ...
# 4395  In the vibrant city-state of Castellane, the r...        624
# 4396  A stunning and magisterial new epic of love, f...        724
# 4397  The Pulitzer Prize–winning, bestselling author...        284
# 4398  Author and single mom Finlay Donovan has been ...        304
# 4399  A devilish thriller with a killer concept: The...        389
#
#                      Format  \
# 0                 Paperback
# 1                 Paperback
# 2                 Paperback
# 3     Mass Market Paperback
# 4     Mass Market Paperback
# ...                     ...
# 4395              Hardcover
# 4396              Hardcover
# 4397              Hardcover
# 4398              Hardcover
# 4399              Hardcover
#
#                                                  Genres    Publication Date  \
# 0     ['Science Fiction', 'Fiction', 'Humor', 'Fanta...    October 12, 1980
# 1     ['Fiction', 'Historical Fiction', 'Mystery', '...     January 1, 1980
# 2     ['Historical Fiction', 'Fiction', 'Fantasy', '...     January 1, 1980
# 3     ['Horror', 'Fiction', 'Thriller', 'Science Fic...  September 29, 1980
# 4     ['Science', 'Nonfiction', 'Physics', 'Astronom...     January 1, 1980
# ...                                                 ...                 ...
# 4395  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...    October 10, 2023
# 4396  ['Fiction', 'Historical Fiction', 'India', 'Au...         May 2, 2023
# 4397  ['Nonfiction', 'Politics', 'Sociology', 'Histo...      March 21, 2023
# 4398  ['Mystery', 'Audiobook', 'Fiction', 'Mystery T...    January 31, 2023
# 4399  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...   February 21, 2023
#
#       Rating  Number of voters
# 0       4.21            283375
# 1       4.14            360732
# 2       4.09            264630
# 3       3.91            226270
# 4       4.39            144686
# ...      ...               ...
# 4395    3.85             12662
# 4396    4.49            111236
# 4397    4.30             25676
# 4398    3.82             46020
# 4399    3.90             19625
#
# [4366 rows x 12 columns]

# %%
df['Format'].unique()
# Out:
# array(['Paperback', 'Mass Market Paperback', 'Hardcover',
#        'Library Binding', 'Kindle Edition', 'hardcover', 'Audio Cassette',
#        'Board Book', 'Board book', 'Broschiert', 'paper', 'ebook',
#        'Unknown Binding', 'Trade Paperback', 'Audio CD', 'Audiobook',
#        'Slipcased Hardcover', 'Print', 'Nook'], dtype=object)

# %%
df['Format'] = df['Format'].replace({
    'Mass Market Paperback': 'Papierowa okładka',
    'Paperback': 'Papierowa okładka',
    'Hardcover': 'Twarda oprawa',
    'Library Binding': 'Oprawa Biblioteczna',
    'Kindle Edition': 'Wersja Kindle',
    'Board Book': 'Kartonowa',
    'Board book': 'Kartonowa',
    'Broschiert': 'Broszura',
    'paper': 'Papier',
    'Unknown Binding': 'Nieznana Oprawa',
    'Trade Paperback': 'Okładka wymienna',
    'Audio CD': 'Płyta CD',
    'Slipcased Hardcover': 'W twardej oprawie',
    'Print': 'Druk',
    'Nook': 'Zilustrowana okładka'
})

# Display unique values after replacement
print(df['Format'].unique())
df
# Out:
# ['Papierowa okładka' 'Twarda oprawa' 'Oprawa Biblioteczna' 'Wersja Kindle'
#  'hardcover' 'Audio Cassette' 'Kartonowa' 'Broszura' 'Papier' 'ebook'
#  'Nieznana Oprawa' 'Okładka wymienna' 'Płyta CD' 'Audiobook'
#  'W twardej oprawie' 'Druk' 'Zilustrowana okładka']
#         id                                               Book  \
# 0        0          The Restaurant at the End of the Universe
# 1        1                               The Name of the Rose
# 2        2                          The Clan of the Cave Bear
# 3        3                                        Firestarter
# 4        4                                             Cosmos
# ...    ...                                                ...
# 4395  4395                                      Sword Catcher
# 4396  4396                              The Covenant of Water
# 4397  4397                                Poverty, by America
# 4398  4398                       Finlay Donovan Jumps the Gun
# 4399  4399  Murder Your Employer: The McMasters Guide to H...
#
#                                     Series Release number              Author  \
# 0     The Hitchhiker's Guide to the Galaxy              2       Douglas Adams
# 1                              Brak danych    Brak danych         Umberto Eco
# 2                         Earth's Children              1        Jean M. Auel
# 3                              Brak danych    Brak danych        Stephen King
# 4                              Brak danych    Brak danych          Carl Sagan
# ...                                    ...            ...                 ...
# 4395                         Sword Catcher              1     Cassandra Clare
# 4396                           Brak danych    Brak danych  Abraham   Verghese
# 4397                           Brak danych    Brak danych     Matthew Desmond
# 4398                        Finlay Donovan              3       Elle Cosimano
# 4399                           Brak danych    Brak danych       Rupert Holmes
#
#                                             Description  Num Pages  \
# 0     Facing annihilation at the hands of the warlik...        250
# 1     The year is 1327. Benedictines in a wealthy It...        536
# 2     This novel of awesome beauty and power is a mo...        512
# 3     The Department of Scientific Intelligence (aka...        564
# 4     The story of fifteen billion years of cosmic e...        384
# ...                                                 ...        ...
# 4395  In the vibrant city-state of Castellane, the r...        624
# 4396  A stunning and magisterial new epic of love, f...        724
# 4397  The Pulitzer Prize–winning, bestselling author...        284
# 4398  Author and single mom Finlay Donovan has been ...        304
# 4399  A devilish thriller with a killer concept: The...        389
#
#                  Format                                             Genres  \
# 0     Papierowa okładka  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1     Papierowa okładka  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2     Papierowa okładka  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3     Papierowa okładka  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4     Papierowa okładka  ['Science', 'Nonfiction', 'Physics', 'Astronom...
# ...                 ...                                                ...
# 4395      Twarda oprawa  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...
# 4396      Twarda oprawa  ['Fiction', 'Historical Fiction', 'India', 'Au...
# 4397      Twarda oprawa  ['Nonfiction', 'Politics', 'Sociology', 'Histo...
# 4398      Twarda oprawa  ['Mystery', 'Audiobook', 'Fiction', 'Mystery T...
# 4399      Twarda oprawa  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...
#
#         Publication Date  Rating  Number of voters
# 0       October 12, 1980    4.21            283375
# 1        January 1, 1980    4.14            360732
# 2        January 1, 1980    4.09            264630
# 3     September 29, 1980    3.91            226270
# 4        January 1, 1980    4.39            144686
# ...                  ...     ...               ...
# 4395    October 10, 2023    3.85             12662
# 4396         May 2, 2023    4.49            111236
# 4397      March 21, 2023    4.30             25676
# 4398    January 31, 2023    3.82             46020
# 4399   February 21, 2023    3.90             19625
#
# [4366 rows x 12 columns]

# %%
df.to_csv("books2.csv")
df
# Out:
#         id                                               Book  \
# 0        0          The Restaurant at the End of the Universe
# 1        1                               The Name of the Rose
# 2        2                          The Clan of the Cave Bear
# 3        3                                        Firestarter
# 4        4                                             Cosmos
# ...    ...                                                ...
# 4395  4395                                      Sword Catcher
# 4396  4396                              The Covenant of Water
# 4397  4397                                Poverty, by America
# 4398  4398                       Finlay Donovan Jumps the Gun
# 4399  4399  Murder Your Employer: The McMasters Guide to H...
#
#                                     Series Release number              Author  \
# 0     The Hitchhiker's Guide to the Galaxy              2       Douglas Adams
# 1                              Brak danych    Brak danych         Umberto Eco
# 2                         Earth's Children              1        Jean M. Auel
# 3                              Brak danych    Brak danych        Stephen King
# 4                              Brak danych    Brak danych          Carl Sagan
# ...                                    ...            ...                 ...
# 4395                         Sword Catcher              1     Cassandra Clare
# 4396                           Brak danych    Brak danych  Abraham   Verghese
# 4397                           Brak danych    Brak danych     Matthew Desmond
# 4398                        Finlay Donovan              3       Elle Cosimano
# 4399                           Brak danych    Brak danych       Rupert Holmes
#
#                                             Description  Num Pages  \
# 0     Facing annihilation at the hands of the warlik...        250
# 1     The year is 1327. Benedictines in a wealthy It...        536
# 2     This novel of awesome beauty and power is a mo...        512
# 3     The Department of Scientific Intelligence (aka...        564
# 4     The story of fifteen billion years of cosmic e...        384
# ...                                                 ...        ...
# 4395  In the vibrant city-state of Castellane, the r...        624
# 4396  A stunning and magisterial new epic of love, f...        724
# 4397  The Pulitzer Prize–winning, bestselling author...        284
# 4398  Author and single mom Finlay Donovan has been ...        304
# 4399  A devilish thriller with a killer concept: The...        389
#
#                  Format                                             Genres  \
# 0     Papierowa okładka  ['Science Fiction', 'Fiction', 'Humor', 'Fanta...
# 1     Papierowa okładka  ['Fiction', 'Historical Fiction', 'Mystery', '...
# 2     Papierowa okładka  ['Historical Fiction', 'Fiction', 'Fantasy', '...
# 3     Papierowa okładka  ['Horror', 'Fiction', 'Thriller', 'Science Fic...
# 4     Papierowa okładka  ['Science', 'Nonfiction', 'Physics', 'Astronom...
# ...                 ...                                                ...
# 4395      Twarda oprawa  ['Fantasy', 'Romance', 'Adult', 'Young Adult',...
# 4396      Twarda oprawa  ['Fiction', 'Historical Fiction', 'India', 'Au...
# 4397      Twarda oprawa  ['Nonfiction', 'Politics', 'Sociology', 'Histo...
# 4398      Twarda oprawa  ['Mystery', 'Audiobook', 'Fiction', 'Mystery T...
# 4399      Twarda oprawa  ['Mystery', 'Fiction', 'Thriller', 'Mystery Th...
#
#         Publication Date  Rating  Number of voters
# 0       October 12, 1980    4.21            283375
# 1        January 1, 1980    4.14            360732
# 2        January 1, 1980    4.09            264630
# 3     September 29, 1980    3.91            226270
# 4        January 1, 1980    4.39            144686
# ...                  ...     ...               ...
# 4395    October 10, 2023    3.85             12662
# 4396         May 2, 2023    4.49            111236
# 4397      March 21, 2023    4.30             25676
# 4398    January 31, 2023    3.82             46020
# 4399   February 21, 2023    3.90             19625
#
# [4366 rows x 12 columns]

# %%
rating_column = 'Rating'

mean_rating = df[rating_column].mean()
std_dev_rating = df[rating_column].std()

num_samples = len(df)

plt.figure(figsize=(10, 6))
sns.histplot(df[rating_column], kde=True, color='blue', label='Oceny książek')
plt.title('Krzywa Gaussa dla ocen')
plt.xlabel('Ocena')
plt.ylabel('Częstotliwość')
plt.legend()
plt.show()

# plt.savefig('chart/bell1')

# %%
format_counts = df['Format'].value_counts()

# Plotting the bar chart
format_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Formaty książek w bibliotece')
plt.xlabel('Format książki')
plt.ylabel('Ilość')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
ax = format_counts.plot(kind='bar', color='yellow', edgecolor='black')
ax.set_ylim(0, 100)  # Set y-axis limit
plt.title('Formaty książek w bibliotece')
plt.xlabel('Format książki')
plt.ylabel('Ilość')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# df['Publication Date'] = df['Publication Date'].str.extract(r'(\w+ \d+, \d+)', expand=False)

df['Publication Date'] = pd.to_datetime(df['Publication Date'], format='%B %d, %Y')

# Extract the year from the datetime column
df['Year'] = df['Publication Date'].dt.year

df_filtered = df[(df['Year'] >= 1980) & (df['Year'] <= 2023)]

# Plotting the line chart
df['Year'].value_counts().sort_index().plot(kind='line', marker='o', color='green')
ax = df_filtered['Year'].value_counts().sort_index().plot(kind='line', color='green', marker='', linestyle='-')
ax.set_xlim(1980, 2023)  # Set x-axis limit
ax.set_ylim(80, 120)  # Set y-axis limit
plt.title('Ilość książek opublikowanych w czasie (1980-2023)')
plt.xlabel('Rok Publikacji')
plt.ylabel('Wolumen')
plt.grid(True)
plt.show()
